# %% [markdown]
# <a href="https://colab.research.google.com/github/massengineer/FYP-ML-Bird-Scarer/blob/main/FYP_YOLO_Third_Model_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Mar  3 11:29:53 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 68.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ##Install YOLOv8

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.5/112.6 GB disk)
#
# OS                     Linux-6.6.113+-x86_64-with-glibc2.35
# Environment            Colab
# Python                 3.12.12
# Install                pip
# Path                   /usr/local/lib/python3.12/dist-packages/ultralytics
# RAM                    12.67 GB
# Disk                   43.5/112.6 GB
# CPU                    Intel Xeon CPU @ 2.00GHz
# CPU count              2
# GPU                    Tesla T4, 14913MiB
# GPU count              1
# CUDA                   12.8
#
# numpy                  ✅ 2.0.2>=1.23.0
# matplotlib             ✅ 3.10.0>=3.3.0
# opencv-python          ✅ 4.13.0.92>=4.6.0
# pillow                 ✅ 11.3.0>=7.1.2
# pyyaml                 ✅ 6.0.3>=5.3.1
# requests               ✅ 2.32.4>=2.23.0
# scipy                  ✅ 1.16.3>=1.4.1
# torch                  ✅ 2.10.0+cu128>=1.8.0
# ...

# %% [markdown]
# ##Train YOLOv8 Model on Custom Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="B4RI3dtoSOywLRiiiPYF")
project = rf.workspace("louiss-workspace-dvwey").project("fyp-intelligent-bird-scarer-3")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 92.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 128.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to FYP-Intelligent-Bird-Scarer-3-1 in yolov8:: 100%|██████████| 2455/2455 [00:00<00:00, 4308.34it/s]

# %%
# !yolo detect train data=/content/FYP-Intelligent-Bird-Scarer-3-1/data.yaml model=yolov8n.pt epochs=200 imgsz=640
# Out:
# ...
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !yolo detect val model=/content/runs/detect/train/weights/best.pt data=/content/FYP-Intelligent-Bird-Scarer-3-1/data.yaml
# Out:
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2325.7±487.6 MB/s, size: 78.6 KB)
# val: Scanning /content/FYP-Intelligent-Bird-Scarer-3-1/valid/labels.cache... 65 images, 27 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 65/65 13.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.9it/s 1.7s
#                    all         65         71       0.52      0.574      0.587       0.47
#                   duck         18         49      0.642      0.449      0.501      0.277
#                  raven         11         11      0.596      0.909      0.871      0.791
#                sparrow          9         11      0.322      0.364       0.39      0.343
# Speed: 5.4ms preprocess, 6.2ms inference, 0.0ms loss, 2.4ms postprocess per image
# ...

# %%
# !yolo detect predict model=/content/runs/detect/train/weights/best.pt conf=0.5 source=/content/FYP-Intelligent-Bird-Scarer-3-1/test/images
# Out:
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/32 /content/FYP-Intelligent-Bird-Scarer-3-1/test/images/005496a27034869a_jpg.rf.91815ccb457b45bbcccecb33ffe89049.jpg: 640x640 1 duck, 8.7ms
# image 2/32 /content/FYP-Intelligent-Bird-Scarer-3-1/test/images/00a7b1f92bc3c26c_jpg.rf.3967a5856050a090713b956aa90df9f4.jpg: 640x640 (no detections), 7.2ms
# image 3/32 /content/FYP-Intelligent-Bird-Scarer-3-1/test/images/01ab055bbc52058c_jpg.rf.4ee22ba7d021fa6e1c712ffc6e7a7f4a.jpg: 640x640 (no detections), 7.2ms
# image 4/32 /content/FYP-Intelligent-Bird-Scarer-3-1/test/images/02f0d65becb9f078_jpg.rf.1555b6cb799f685474c3f96dec837a7f.jpg: 640x640 1 duck, 7.2ms
# image 5/32 /content/FYP-Intelligent-Bird-Scarer-3-1/test/images/04ea8cb7f726b3f9_jpg.rf.2d63c64d72775b37674176618c29c846.jpg: 640x640 1 duck, 7.1ms
# ...

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg'):
  display(Image(filename=image_path, height=600))
  print('\n')

# %%
Image(filename=f'/content/runs/detect/train/results.png', width=1000)

# %%
# Create model folder to store model weights and train results
# !mkdir /content/my_third_trained_model
# !cp /content/runs/detect/train/weights/best.pt /content/my_third_trained_model/my_third_trained_model.pt
# !cp -r /content/runs/detect/train /content/my_third_trained_model

# Zip into "my_model.zip"
# %cd my_third_trained_model
# !zip /content/my_third_trained_model.zip my_third_trained_model.pt
# !zip -r /content/my_third_trained_model.zip train
# %cd /content
# Out:
# /content/my_third_trained_model
#   adding: my_third_trained_model.pt (deflated 10%)
#   adding: train/ (stored 0%)
#   adding: train/val_batch2_labels.jpg (deflated 7%)
#   adding: train/confusion_matrix.png (deflated 33%)
#   adding: train/train_batch2.jpg (deflated 1%)
#   adding: train/confusion_matrix_normalized.png (deflated 27%)
#   adding: train/args.yaml (deflated 52%)
#   adding: train/val_batch2_pred.jpg (deflated 7%)
#   adding: train/train_batch1.jpg (deflated 2%)
#   adding: train/BoxPR_curve.png (deflated 16%)
#   adding: train/results.csv (deflated 62%)
#   adding: train/weights/ (stored 0%)
#   adding: train/weights/last.pt (deflated 10%)
#   adding: train/weights/best.pt (deflated 10%)
#   adding: train/labels.jpg (deflated 29%)
#   adding: train/results.png (deflated 6%)
#   adding: train/val_batch1_labels.jpg (deflated 6%)
#   adding: train/BoxR_curve.png (deflated 13%)
#   adding: train/BoxF1_curve.png (deflated 11%)
# ...

# %%
# This takes forever for some reason, you can also just download the model from the sidebar
from google.colab import files

files.download('/content/my_third_trained_model.zip')
