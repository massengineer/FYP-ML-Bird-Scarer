# %% [markdown]
# <a href="https://colab.research.google.com/github/massengineer/FYP-ML-Bird-Scarer/blob/main/FYP_YOLO_Sixth_Model_v3_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Apr 12 13:10:22 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ##Install YOLOv8

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.1/112.6 GB disk)
#
# OS                     Linux-6.6.113+-x86_64-with-glibc2.35
# Environment            Colab
# Python                 3.12.13
# Install                pip
# Path                   /usr/local/lib/python3.12/dist-packages/ultralytics
# RAM                    12.67 GB
# Disk                   43.1/112.6 GB
# CPU                    Intel Xeon CPU @ 2.00GHz
# CPU count              2
# GPU                    Tesla T4, 14913MiB
# GPU count              1
# CUDA                   12.8
#
# numpy                  ✅ 2.0.2>=1.23.0
# matplotlib             ✅ 3.10.0>=3.3.0
# opencv-python          ✅ 4.13.0.92>=4.6.0
# pillow                 ✅ 11.3.0>=7.1.2
# pyyaml                 ✅ 6.0.3>=5.3.1
# requests               ✅ 2.32.4>=2.23.0
# scipy                  ✅ 1.16.3>=1.4.1
# torch                  ✅ 2.10.0+cu128>=1.8.0
# ...

# %% [markdown]
# ##Train YOLOv8 Model on Custom Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="B4RI3dtoSOywLRiiiPYF")
project = rf.workspace("louiss-workspace-dvwey").project("fyp-intelligent-bird-scarer-5")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.5/169.5 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 88.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 138.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to FYP-Intelligent-Bird-Scarer-5-1 in yolov8:: 100%|██████████| 733/733 [00:00<00:00, 6566.23it/s]

# %%
# !yolo detect train data=/content/FYP-Intelligent-Bird-Scarer-5-1/data.yaml model=yolov8s.pt epochs=300 patience=50 batch=64 imgsz=640
# Out:
# ...
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !yolo detect val model=/content/runs/detect/train/weights/best.pt data=/content/FYP-Intelligent-Bird-Scarer-5-1/data.yaml
# Out:
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2696.7±829.5 MB/s, size: 107.9 KB)
# val: Scanning /content/FYP-Intelligent-Bird-Scarer-5-1/valid/labels.cache... 71 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 71/71 1.7Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.2it/s 2.3s
#                    all         71         90      0.728      0.684      0.707      0.521
#                   duck         16         29      0.921      0.402      0.647       0.46
#                  raven         30         39      0.625      0.923      0.848      0.661
#                sparrow         19         22      0.639      0.727      0.626      0.442
# Speed: 5.2ms preprocess, 9.6ms inference, 0.0ms loss, 8.7ms postprocess per image
# ...

# %%
# !yolo detect predict model=/content/runs/detect/train/weights/best.pt conf=0.5 source=/content/FYP-Intelligent-Bird-Scarer-5-1/test/images
# Out:
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/35 /content/FYP-Intelligent-Bird-Scarer-5-1/test/images/00ba3d4a61b04eec_jpg.rf.0d2e3429d50be6b66daad51153c0a0fc.jpg: 640x640 1 raven, 15.2ms
# image 2/35 /content/FYP-Intelligent-Bird-Scarer-5-1/test/images/0110c5092753827f_jpg.rf.35c409d17e8469acd2167b27f71d8b6c.jpg: 640x640 1 duck, 15.2ms
# image 3/35 /content/FYP-Intelligent-Bird-Scarer-5-1/test/images/01297ff3e3d45ebf_jpg.rf.d7f46096fb75e4237db39a3adee3b9a9.jpg: 640x640 1 duck, 1 raven, 15.1ms
# image 4/35 /content/FYP-Intelligent-Bird-Scarer-5-1/test/images/0715efc2cc093401_jpg.rf.520bc036e3ebedace5301a5ec06140f3.jpg: 640x640 (no detections), 16.1ms
# image 5/35 /content/FYP-Intelligent-Bird-Scarer-5-1/test/images/155a996dacd85053_jpg.rf.1f4cc7d401cd927f6041cba936282972.jpg: 640x640 2 ravens, 16.1ms
# ...

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg'):
  display(Image(filename=image_path, height=600))
  print('\n')

# %%
Image(filename=f'/content/runs/detect/train/results.png', width=1000)

# %%
# Create model folder to store model weights and train results
# !mkdir /content/my_sixth_trained_model_v3
# !cp /content/runs/detect/train/weights/best.pt /content/my_sixth_trained_model_v3/my_sixth_trained_model_v3.pt
# !cp -r /content/runs/detect/train /content/my_sixth_trained_model_v3

# Zip into "my_model.zip"
# %cd my_sixth_trained_model_v3
# !zip /content/my_sixth_trained_model_v3.zip my_sixth_trained_model_v3.pt
# !zip -r /content/my_sixth_trained_model_v3.zip train
# %cd /content
# Out:
# /content/my_sixth_trained_model_v3
#   adding: my_sixth_trained_model_v3.pt (deflated 8%)
#   adding: train/ (stored 0%)
#   adding: train/val_batch0_labels.jpg (deflated 5%)
#   adding: train/args.yaml (deflated 52%)
#   adding: train/results.csv (deflated 59%)
#   adding: train/BoxF1_curve.png (deflated 10%)
#   adding: train/confusion_matrix.png (deflated 30%)
#   adding: train/train_batch2.jpg (deflated 1%)
#   adding: train/weights/ (stored 0%)
#   adding: train/weights/last.pt (deflated 8%)
#   adding: train/weights/best.pt (deflated 8%)
#   adding: train/BoxP_curve.png (deflated 10%)
#   adding: train/confusion_matrix_normalized.png (deflated 25%)
#   adding: train/train_batch0.jpg (deflated 1%)
#   adding: train/BoxR_curve.png (deflated 13%)
#   adding: train/results.png (deflated 5%)
#   adding: train/train_batch1.jpg (deflated 1%)
#   adding: train/val_batch0_pred.jpg (deflated 5%)
#   adding: train/BoxPR_curve.png (deflated 16%)
#   adding: train/labels.jpg (deflated 32%)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# This takes forever for some reason, you can also just download the model from the sidebar
from google.colab import files

files.download('/content/my_sixth_trained_model_v3.zip')
